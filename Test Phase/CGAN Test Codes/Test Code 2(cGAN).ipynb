# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("davilsena/ckdataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/davilsena/ckdataset?dataset_version_number=2...
# 100%|██████████| 2.48M/2.48M [00:00<00:00, 156MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/davilsena/ckdataset/versions/2

# %%
import numpy as np
#load the dataset
def load_dataset(path):
    # Placeholder function to load dataset
    # Replace this with actual loading and preprocessing code
    images = np.random.randn(1000, 64, 64, 3)  # Dummy data
    labels = np.random.randint(0, 8, 1000)     # Dummy labels (8 emotion classes)
    images = (images - 127.5) / 127.5          # Normalize to [-1, 1]
    return images, labels

images, labels = load_dataset('/root/.cache/kagglehub/datasets/davilsena/ckdataset/versions/2')

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Input,
    Dense,
    LeakyReLU,
    Reshape,
    Flatten,
    Conv2D,
    Conv2DTranspose,
    Dropout,
    Concatenate,
    GlobalAveragePooling2D,
    Layer
)
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
import numpy as np

def build_generator(latent_dim, num_classes):
    noise_input = Input(shape=(latent_dim,), name="noise_input")
    label_input = Input(shape=(1,), name="label_input")

    # Embed label into the same dimension as noise
    label_embedding = Dense(latent_dim, activation="relu")(label_input)

    # Combine noise and embedded label
    merged_input = Concatenate()([noise_input, label_embedding])

    # Fully connected layer
    x = Dense(128 * 8 * 8, activation="relu")(merged_input)
    x = Reshape((8, 8, 128))(x)

    # Upsampling with Conv2DTranspose
    x = Conv2DTranspose(128, kernel_size=4, strides=2, padding="same", activation="relu")(x)
    x = Conv2DTranspose(64, kernel_size=4, strides=2, padding="same", activation="relu")(x)
    # Adjust the upsampling layers to output the desired shape (32, 32, 3)
    x = Conv2DTranspose(64, kernel_size=4, strides=2, padding="same", activation="relu")(x)
    x = Conv2D(3, kernel_size=3, padding="same", activation="tanh")(x)  # Output layer with 3 channels and tanh activation


    # Remove unnecessary resizing and ResNet50 part

    return Model([noise_input, label_input], x, name="Generator") # Return x directly

# %%
def build_discriminator(image_shape, num_classes):
    image_input = Input(shape=image_shape, name="image_input")
    label_input = Input(shape=(1,), name="label_input")

    # Embed label into the image dimensions
    label_embedding = Dense(np.prod(image_shape))(label_input)
    label_embedding = Reshape(image_shape)(label_embedding)

    # Combine image and label
    merged_input = Concatenate(axis=-1)([image_input, label_embedding])

    # ResNet50 for feature extraction
    resnet_base = ResNet50(weights="imagenet", include_top=False, input_shape=image_shape)
    for layer in resnet_base.layers:
        layer.trainable = False  # Freeze ResNet50 layers

    # Extract ResNet features
    resnet_features = resnet_base(image_input)

    # Flatten VGG features for concatenation
    flat_features = Flatten()(resnet_features)

    # Embed the label input
    label_embedding = Dense(np.prod(flat_features.shape[1:]))(label_input)
    label_embedding = LeakyReLU(alpha=0.2)(label_embedding)

    # Combine flat VGG features and label embedding
    merged = Concatenate()([flat_features, label_embedding])

    # Fully connected layers
    x = Dense(128)(merged)
    x = LeakyReLU(alpha=0.2)(x)
    validity = Dense(1, activation="sigmoid", name="validity")(x)

    return Model([image_input, label_input], validity, name="Discriminator")

# %%
# Parameters for models
latent_dim = 100
num_classes = 10
image_shape = (64, 64, 3)

# Instantiate models
generator = build_generator(latent_dim, num_classes)
discriminator = build_discriminator(image_shape, num_classes)

# Print model summaries
print(generator.summary())
print(discriminator.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ label_input (InputLayer)  │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ noise_input (InputLayer)  │ (None, 100)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 100)            │            200 │ label_input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 200)            │              0 │ noise_input[0][0],     │
# │                           │                        │                │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 8192)           │      1,646,592 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 8, 8, 128)      │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 128)    │        262,272 │ reshape[0][0]          │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 64)     │        131,136 │ conv2d_transpose[0][0] │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 64)     │         65,600 │ conv2d_transpose_1[0]… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 64, 64, 3)      │          1,731 │ conv2d_transpose_2[0]… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,107,531 (8.04 MB)
#  Trainable params: 2,107,531 (8.04 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Model: "Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image_input (InputLayer)  │ (None, 64, 64, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ label_input (InputLayer)  │ (None, 1)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet50 (Functional)     │ (None, 2, 2, 2048)     │     23,587,712 │ image_input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 8192)           │         16,384 │ label_input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 8192)           │              0 │ resnet50[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 8192)           │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 16384)          │              0 │ flatten[0][0],         │
# │ (Concatenate)             │                        │                │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 128)            │      2,097,280 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 128)            │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ validity (Dense)          │ (None, 1)              │            129 │ leaky_re_lu_1[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,701,505 (98.04 MB)
#  Trainable params: 2,113,793 (8.06 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# None

# %%
#cGAN Model
def build_cgan(generator, discriminator, latent_dim, ttur_gen_lr, ttur_disc_lr): # Added ttur_gen_lr as an argument
    discriminator.compile(optimizer=Adam(ttur_disc_lr, 0.5), loss="binary_crossentropy", metrics=["accuracy"])
    discriminator.trainable = False

    noise_input = Input(shape=(latent_dim,), name="noise_input")
    label_input = Input(shape=(1,), name="label_input")
    generated_img = generator([noise_input, label_input])
    validity = discriminator([generated_img, label_input])

    cgan = Model([noise_input, label_input], validity, name="cGAN")
    cgan.compile(optimizer=Adam(ttur_gen_lr, 0.5), loss="binary_crossentropy") # Now using the correct learning rate
    return cgan

# %%
#load the dataset
def load_dataset(path):
    # Placeholder function to load dataset
    # Replace this with actual loading and preprocessing code
    images = np.random.randn(1000, 64, 64, 3)  # Dummy data
    labels = np.random.randint(0, 8, 1000)     # Dummy labels (8 emotion classes)
    images = (images - 127.5) / 127.5          # Normalize to [-1, 1]
    return images, labels

images, labels = load_dataset('/root/.cache/kagglehub/datasets/nelgiriyewithana/emotions/versions/1')

# %%
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Embedding, Concatenate
from tensorflow.keras.optimizers import Adam



batch_size = 64
epochs = 5

# Build and compile models
generator = build_generator(latent_dim, num_classes)
discriminator = build_discriminator(image_shape, num_classes)
discriminator.compile(optimizer=Adam(0.0002, 0.5), loss='binary_crossentropy', metrics=['accuracy'])

ttur_gen_lr = 0.0002  # Example value, adjust as needed
ttur_disc_lr = 0.0002  # Example value, adjust as needed

cgan = build_cgan(generator, discriminator,latent_dim, ttur_gen_lr, ttur_disc_lr)
cgan.compile(optimizer=Adam(0.0002, 0.5), loss='binary_crossentropy')

# Custom Data Generator for cGAN Training
class CGANDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size, latent_dim, num_classes):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.latent_dim = latent_dim
        self.num_classes = num_classes

    def __len__(self):
        return len(self.images) // self.batch_size

    def __getitem__(self, index):
        # Real images and labels for discriminator
        idx = np.random.randint(0, self.images.shape[0], self.batch_size // 2)
        real_images = self.images[idx]
        real_labels = self.labels[idx]

        # Fake images and labels for discriminator
        noise = np.random.normal(0, 1, (self.batch_size // 2, self.latent_dim))
        fake_labels = np.random.randint(0, self.num_classes, self.batch_size // 2)
        fake_images = generator.predict([noise, fake_labels])

        # Inputs and labels for discriminator
        discriminator_x = np.concatenate([real_images, fake_images])
        discriminator_y = np.concatenate([np.ones((self.batch_size // 2, 1)), np.zeros((self.batch_size // 2, 1))])
        discriminator_labels = np.concatenate([real_labels, fake_labels])

        return ([discriminator_x, discriminator_labels], discriminator_y)

# Dummy dataset for demonstration
images = np.random.rand(1000, *image_shape)
labels = np.random.randint(0, num_classes, 1000)

data_generator = CGANDataGenerator(images, labels, batch_size, latent_dim, num_classes)

# Training loop
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")
    for batch_idx in range(len(data_generator)):
        # 1. Train Discriminator
        discriminator_x, discriminator_y = data_generator[batch_idx]
        d_loss = discriminator.train_on_batch(discriminator_x, discriminator_y)

        # 2. Train Generator (via the combined model)
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        random_labels = np.random.randint(0, num_classes, batch_size)
        g_loss = cgan.train_on_batch([noise, random_labels], np.ones((batch_size, 1)))

    # Print progress

        print(f"Epoch: {epoch + 1}/{epochs}, Discriminator Loss: {d_loss[0]}, Generator Loss: {g_loss}")
# Save the models
generator.save("generator.h5")
discriminator.save("discriminator.h5")
cgan.save("cgan.h5")
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# Epoch: 1/5, Discriminator Loss: 0.8840395212173462, Generator Loss: [array(0.8840395, dtype=float32), array(0.8840395, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch: 1/5, Discriminator Loss: 0.8852442502975464, Generator Loss: [array(0.88524425, dtype=float32), array(0.88524425, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x786fa006f100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x786f8ffc7880> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch: 1/5, Discriminator Loss: 0.8862809538841248, Generator Loss: [array(0.88628095, dtype=float32), array(0.88628095, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 1/5, Discriminator Loss: 0.8873397707939148, Generator Loss: [array(0.8873398, dtype=float32), array(0.8873398, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 1/5, Discriminator Loss: 0.888497531414032, Generator Loss: [array(0.88849753, dtype=float32), array(0.88849753, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 1/5, Discriminator Loss: 0.8906843662261963, Generator Loss: [array(0.89068437, dtype=float32), array(0.89068437, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch: 1/5, Discriminator Loss: 0.8931645154953003, Generator Loss: [array(0.8931645, dtype=float32), array(0.8931645, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 1/5, Discriminator Loss: 0.8961971402168274, Generator Loss: [array(0.89619714, dtype=float32), array(0.89619714, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Epoch: 1/5, Discriminator Loss: 0.8998996019363403, Generator Loss: [array(0.8998996, dtype=float32), array(0.8998996, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch: 1/5, Discriminator Loss: 0.9049517512321472, Generator Loss: [array(0.90495175, dtype=float32), array(0.90495175, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 1/5, Discriminator Loss: 0.9125804901123047, Generator Loss: [array(0.9125805, dtype=float32), array(0.9125805, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 1/5, Discriminator Loss: 0.9208381772041321, Generator Loss: [array(0.9208382, dtype=float32), array(0.9208382, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 1/5, Discriminator Loss: 0.9283549189567566, Generator Loss: [array(0.9283549, dtype=float32), array(0.9283549, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 1/5, Discriminator Loss: 0.9351497888565063, Generator Loss: [array(0.9351498, dtype=float32), array(0.9351498, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch: 1/5, Discriminator Loss: 0.9416624903678894, Generator Loss: [array(0.9416625, dtype=float32), array(0.9416625, dtype=float32), array(0.5, dtype=float32)]
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 2/5, Discriminator Loss: 0.9477616548538208, Generator Loss: [array(0.94776165, dtype=float32), array(0.94776165, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 2/5, Discriminator Loss: 0.9534485936164856, Generator Loss: [array(0.9534486, dtype=float32), array(0.9534486, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 2/5, Discriminator Loss: 0.9586458206176758, Generator Loss: [array(0.9586458, dtype=float32), array(0.9586458, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 2/5, Discriminator Loss: 0.9635807871818542, Generator Loss: [array(0.9635808, dtype=float32), array(0.9635808, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 2/5, Discriminator Loss: 0.9685704112052917, Generator Loss: [array(0.9685704, dtype=float32), array(0.9685704, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Epoch: 2/5, Discriminator Loss: 0.9730907678604126, Generator Loss: [array(0.97309077, dtype=float32), array(0.97309077, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 2/5, Discriminator Loss: 0.9775429368019104, Generator Loss: [array(0.97754294, dtype=float32), array(0.97754294, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch: 2/5, Discriminator Loss: 0.981880247592926, Generator Loss: [array(0.98188025, dtype=float32), array(0.98188025, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 2/5, Discriminator Loss: 0.9865303635597229, Generator Loss: [array(0.98653036, dtype=float32), array(0.98653036, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 2/5, Discriminator Loss: 0.9908115267753601, Generator Loss: [array(0.9908115, dtype=float32), array(0.9908115, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 2/5, Discriminator Loss: 0.994933545589447, Generator Loss: [array(0.99493355, dtype=float32), array(0.99493355, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Epoch: 2/5, Discriminator Loss: 0.998818576335907, Generator Loss: [array(0.9988186, dtype=float32), array(0.9988186, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 2/5, Discriminator Loss: 1.0028222799301147, Generator Loss: [array(1.0028223, dtype=float32), array(1.0028223, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch: 2/5, Discriminator Loss: 1.0068418979644775, Generator Loss: [array(1.0068419, dtype=float32), array(1.0068419, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 2/5, Discriminator Loss: 1.0108400583267212, Generator Loss: [array(1.01084, dtype=float32), array(1.01084, dtype=float32), array(0.5, dtype=float32)]
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0143429040908813, Generator Loss: [array(1.0143429, dtype=float32), array(1.0143429, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch: 3/5, Discriminator Loss: 1.0183873176574707, Generator Loss: [array(1.0183873, dtype=float32), array(1.0183873, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 3/5, Discriminator Loss: 1.0221894979476929, Generator Loss: [array(1.0221895, dtype=float32), array(1.0221895, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0261157751083374, Generator Loss: [array(1.0261158, dtype=float32), array(1.0261158, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch: 3/5, Discriminator Loss: 1.0297309160232544, Generator Loss: [array(1.0297309, dtype=float32), array(1.0297309, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0329400300979614, Generator Loss: [array(1.03294, dtype=float32), array(1.03294, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0366507768630981, Generator Loss: [array(1.0366508, dtype=float32), array(1.0366508, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Epoch: 3/5, Discriminator Loss: 1.0400288105010986, Generator Loss: [array(1.0400288, dtype=float32), array(1.0400288, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 3/5, Discriminator Loss: 1.043445348739624, Generator Loss: [array(1.0434453, dtype=float32), array(1.0434453, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0465176105499268, Generator Loss: [array(1.0465176, dtype=float32), array(1.0465176, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0496079921722412, Generator Loss: [array(1.049608, dtype=float32), array(1.049608, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 3/5, Discriminator Loss: 1.052294373512268, Generator Loss: [array(1.0522944, dtype=float32), array(1.0522944, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0554815530776978, Generator Loss: [array(1.0554816, dtype=float32), array(1.0554816, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Epoch: 3/5, Discriminator Loss: 1.058234691619873, Generator Loss: [array(1.0582347, dtype=float32), array(1.0582347, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 3/5, Discriminator Loss: 1.0608677864074707, Generator Loss: [array(1.0608678, dtype=float32), array(1.0608678, dtype=float32), array(0.5, dtype=float32)]
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 4/5, Discriminator Loss: 1.0640028715133667, Generator Loss: [array(1.0640029, dtype=float32), array(1.0640029, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 4/5, Discriminator Loss: 1.067041039466858, Generator Loss: [array(1.067041, dtype=float32), array(1.067041, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 4/5, Discriminator Loss: 1.0701303482055664, Generator Loss: [array(1.0701303, dtype=float32), array(1.0701303, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Epoch: 4/5, Discriminator Loss: 1.073337435722351, Generator Loss: [array(1.0733374, dtype=float32), array(1.0733374, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch: 4/5, Discriminator Loss: 1.0762333869934082, Generator Loss: [array(1.0762334, dtype=float32), array(1.0762334, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 4/5, Discriminator Loss: 1.0794532299041748, Generator Loss: [array(1.0794532, dtype=float32), array(1.0794532, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 4/5, Discriminator Loss: 1.0823856592178345, Generator Loss: [array(1.0823857, dtype=float32), array(1.0823857, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 4/5, Discriminator Loss: 1.0852291584014893, Generator Loss: [array(1.0852292, dtype=float32), array(1.0852292, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 4/5, Discriminator Loss: 1.0882692337036133, Generator Loss: [array(1.0882692, dtype=float32), array(1.0882692, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Epoch: 4/5, Discriminator Loss: 1.0913587808609009, Generator Loss: [array(1.0913588, dtype=float32), array(1.0913588, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 4/5, Discriminator Loss: 1.0938972234725952, Generator Loss: [array(1.0938972, dtype=float32), array(1.0938972, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch: 4/5, Discriminator Loss: 1.0966887474060059, Generator Loss: [array(1.0966887, dtype=float32), array(1.0966887, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 4/5, Discriminator Loss: 1.0991538763046265, Generator Loss: [array(1.0991539, dtype=float32), array(1.0991539, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch: 4/5, Discriminator Loss: 1.1018503904342651, Generator Loss: [array(1.1018504, dtype=float32), array(1.1018504, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 4/5, Discriminator Loss: 1.104831576347351, Generator Loss: [array(1.1048316, dtype=float32), array(1.1048316, dtype=float32), array(0.5, dtype=float32)]
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Epoch: 5/5, Discriminator Loss: 1.1077440977096558, Generator Loss: [array(1.1077441, dtype=float32), array(1.1077441, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 5/5, Discriminator Loss: 1.11065673828125, Generator Loss: [array(1.1106567, dtype=float32), array(1.1106567, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 5/5, Discriminator Loss: 1.113248586654663, Generator Loss: [array(1.1132486, dtype=float32), array(1.1132486, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 5/5, Discriminator Loss: 1.116050362586975, Generator Loss: [array(1.1160504, dtype=float32), array(1.1160504, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 5/5, Discriminator Loss: 1.1186342239379883, Generator Loss: [array(1.1186342, dtype=float32), array(1.1186342, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Epoch: 5/5, Discriminator Loss: 1.1215085983276367, Generator Loss: [array(1.1215086, dtype=float32), array(1.1215086, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 5/5, Discriminator Loss: 1.1241012811660767, Generator Loss: [array(1.1241013, dtype=float32), array(1.1241013, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 5/5, Discriminator Loss: 1.1271337270736694, Generator Loss: [array(1.1271337, dtype=float32), array(1.1271337, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Epoch: 5/5, Discriminator Loss: 1.130027413368225, Generator Loss: [array(1.1300274, dtype=float32), array(1.1300274, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 5/5, Discriminator Loss: 1.132969856262207, Generator Loss: [array(1.1329699, dtype=float32), array(1.1329699, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch: 5/5, Discriminator Loss: 1.1356971263885498, Generator Loss: [array(1.1356971, dtype=float32), array(1.1356971, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch: 5/5, Discriminator Loss: 1.1388559341430664, Generator Loss: [array(1.1388559, dtype=float32), array(1.1388559, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 5/5, Discriminator Loss: 1.141390085220337, Generator Loss: [array(1.1413901, dtype=float32), array(1.1413901, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 5/5, Discriminator Loss: 1.1443793773651123, Generator Loss: [array(1.1443794, dtype=float32), array(1.1443794, dtype=float32), array(0.5, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch: 5/5, Discriminator Loss: 1.1469229459762573, Generator Loss: [array(1.146923, dtype=float32), array(1.146923, dtype=float32), array(0.5, dtype=float32)]
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !pip install tensorflow scipy


import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from scipy.stats import entropy


def calculate_inception_score(generator, latent_dim, num_classes, n_images=5000, batch_size=128):
    """
    Calculate the Inception Score for a GAN model.

    Args:
    - generator: The trained generator model.
    - latent_dim: Latent space dimension used by the generator.
    - num_classes: Number of classes for the conditional GAN.
    - n_images: Total number of images to generate for evaluation.
    - batch_size: Batch size for generating images.

    Returns:
    - mean IS score and standard deviation.
    """
    # Load pre-trained InceptionV3 model
    inception_model = InceptionV3(include_top=True, weights="imagenet")
    inception_model = Model(inputs=inception_model.input, outputs=inception_model.get_layer("avg_pool").output)

    # Generate images and their corresponding labels
    n_batches = n_images // batch_size
    preds = []
    for _ in range(n_batches):
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        labels = np.random.randint(0, num_classes, batch_size)
        generated_images = generator.predict([noise, labels], verbose=0)

        # Resize images to (299, 299, 3) for InceptionV3 compatibility
        resized_images = tf.image.resize(generated_images, (299, 299)).numpy()

        # Normalize images to [-1, 1] -> [0, 1]
        normalized_images = (resized_images + 1) / 2.0
        preds.append(inception_model.predict(normalized_images, verbose=0))

    preds = np.concatenate(preds, axis=0)

    # Compute probabilities and the Inception Score
    scores = []
    for pred in preds:
        # Reshape pred to have shape (1, -1) to calculate entropy along axis=1
        pred = pred.reshape(1, -1)
        p_y = np.mean(pred, axis=0)
        kl_div = entropy(pred, p_y, axis=1)
        scores.append(np.exp(np.mean(kl_div)))

    return np.mean(scores), np.std(scores)
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
mean_is, std_is = calculate_inception_score(generator, latent_dim, num_classes, n_images, batch_size)
print(f"Mean Inception Score: {mean_is:.4f}") # Print the mean IS score
print(f"Inception Score: {mean_is:.4f} ± {std_is:.4f}")
# Out:
# Mean Inception Score: 1.0000
# Inception Score: 1.0000 ± 0.0000
